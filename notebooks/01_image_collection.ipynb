# %% [markdown]
# # 1. Import Dependencies

# %%
# !pip3 install opencv-python
# Out:
# ...
# WARNING: You are using pip version 21.1.3; however, version 22.0.3 is available.
# You should consider upgrading via the '/Users/apple/Documents/Programming Language/Python/Tensorflow Object Detection/TFODCourse/tfod/bin/python3 -m pip install --upgrade pip' command.

# %%
# Import opencv
import cv2 

# Import uuid
import uuid

# Import Operating System
import os

# Import time
import time

# %%
# cap = cv2.VideoCapture(0)
# while cap.isOpened():
#     ret, frame = cap.read()
    
#     cv2.imshow('Defective', frame)
    
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break
# cap.release()
# cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/l7/g92szp4n1zs9pq324kz_7wq40000gn/T/ipykernel_47435/1714276890.py in <module>
#       1 cap = cv2.VideoCapture(0)
#       2 while cap.isOpened():
# ----> 3     ret, frame = cap.read()
#       4
#       5     cv2.imshow('Defective', frame)
#
# KeyboardInterrupt:

# %% [markdown]
# # 2. Define Images to Collect

# %%
labels = ['detectivewasher']
number_imgs = 15

# %%
labels = [ 'nondetectivewasher']
number_imgs = 15

# %%
labels
# Out:
# ['nondetectivewasher']

# %% [markdown]
# # 3. Setup Folders

# %%
IMAGES_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'collectedimages')

# %%
print(IMAGES_PATH)
# Out:
# Tensorflow/workspace/images/collectedimages

# %%
os.name
# Out:
# 'posix'

# %%
if not os.path.exists(IMAGES_PATH):
    if os.name == 'posix':
        # !mkdir -p {IMAGES_PATH}
    if os.name == 'nt':
         # !mkdir {IMAGES_PATH}
for label in labels:
    path = os.path.join(IMAGES_PATH, label)
    if not os.path.exists(path):
        # !mkdir {path}

# %% [markdown]
# # 4. Capture Images

# %%
for label in labels:
    cap = cv2.VideoCapture(1) ## connerct to our webcam or capture device
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(number_imgs):
        print('Collecting image {}'.format(imgnum))
        ret, frame = cap.read()
        imgname = os.path.join(IMAGES_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imgname, frame)
        cv2.imshow('frame', frame)
        time.sleep(3)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 5. Image Labelling

# %%
# !pip3 install --upgrade pyqt5 lxml
# Out:
# ...
# WARNING: You are using pip version 21.1.3; however, version 22.0.3 is available.
# You should consider upgrading via the '/Users/apple/Documents/Programming Language/Python/Tensorflow Object Detection/TFODCourse/tfod/bin/python3 -m pip install --upgrade pip' command.

# %%
import os

# %%
LABELIMG_PATH = os.path.join('Tensorflow', 'labelimg')

# %%
if not os.path.exists(LABELIMG_PATH):
    # !mkdir {LABELIMG_PATH}
    # !git clone https://github.com/tzutalin/labelImg {LABELIMG_PATH}

# %%
LABELIMG_PATH

# %%
if os.name == 'posix':
    # !cd {LABELIMG_PATH} && pyrcc5 -o libs/resources.py resources.qrc
if os.name =='nt':
    # !cd {LABELIMG_PATH} && make qt5py3

# %%
# !cd {LABELIMG_PATH} && python3 labelImg.py
# Out:
# 2022-03-28 23:12:11.107 Python[47580:5787432] TSM AdjustCapsLockLEDForKeyTransitionHandling - _ISSetPhysicalKeyboardCapsLockLED Inhibit
# Image:/Users/apple/Documents/Programming Language/Python/Tensorflow Object Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/detectivewasher/detectivewasher.3873640c-af0a-11ec-a954-787b8aba95a4.jpg -> Annotation:/Users/apple/Documents/Programming Language/Python/Tensorflow Object Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/detectivewasher/detectivewasher.3873640c-af0a-11ec-a954-787b8aba95a4.xml
# ...

# %% [markdown]
# # 6. Move them into a Training and Testing Partition

# %% [markdown]
# # OPTIONAL - 7. Compress them for Colab Training

# %%
TRAIN_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'train')
TEST_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'test')
ARCHIVE_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'archive.tar.gz')

# %%
# !tar -czf {ARCHIVE_PATH} {TRAIN_PATH} {TEST_PATH}
